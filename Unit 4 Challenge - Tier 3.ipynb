# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
print(properties.head())
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()
properties = properties.reset_index()
print(properties)
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001          91448.98487          82202.77314
# 2     Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3                 Barnet  E09000003          93284.51832          93190.16963
# 4                 Bexley  E09000004          64958.09036          64787.92069
# 5                  Brent  E09000005          71306.56698          72022.26197
# 6                Bromley  E09000006          81671.47692          81657.55944
# 7                 Camden  E09000007          120932.8881          119508.8622
# 8                Croydon  E09000008          69158.16225          68951.09542
# 9                 Ealing  E09000009          79885.89069          80897.06551
# 10               Enfield  E09000010          72514.69096          73155.19746
# ...

# %%
# Assign the values of the first row to your column headings .
# Hint: recall the .columns feature of DataFrames, as well as the iloc[] method.

# year = 1994
# month = 11

# for index, item in enumerate(properties):
#     # print(index)
#     year_string = str(year)
#     if month < 10:
#         month_string = "0" + str(month)

#     else:
#         month_string = str(month)
#     properties.iloc[0, index] = year_string + "-" + month_string
#     if month < 12:
#         month += 1
#     else:
#         month = 1
#         year += 1


properties.iloc[0, 0] = "ward_name"
properties.iloc[0, 1] = "ward_id"

print(properties.iloc[0, :].head(30))
# Out:
# index              ward_name
# 0                    ward_id
# 1        1995-01-01 00:00:00
# 2        1995-02-01 00:00:00
# 3        1995-03-01 00:00:00
# 4        1995-04-01 00:00:00
# 5        1995-05-01 00:00:00
# 6        1995-06-01 00:00:00
# 7        1995-07-01 00:00:00
# 8        1995-08-01 00:00:00
# 9        1995-09-01 00:00:00
# 10       1995-10-01 00:00:00
# 11       1995-11-01 00:00:00
# 12       1995-12-01 00:00:00
# 13       1996-01-01 00:00:00
# 14       1996-02-01 00:00:00
# 15       1996-03-01 00:00:00
# 16       1996-04-01 00:00:00
# 17       1996-05-01 00:00:00
# 18       1996-06-01 00:00:00
# 19       1996-07-01 00:00:00
# 20       1996-08-01 00:00:00
# 21       1996-09-01 00:00:00
# 22       1996-10-01 00:00:00
# 23       1996-11-01 00:00:00
# 24       1996-12-01 00:00:00
# 25       1997-01-01 00:00:00
# 26       1997-02-01 00:00:00
# 27       1997-03-01 00:00:00
# 28       1997-04-01 00:00:00
# Name: 0, dtype: object

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties.columns = properties.iloc[0, :]
# properties.rename(columns={properties.columns[0]: "WARD_NAME", properties.columns[1]: "WARD_ID"}, inplace=True)
properties = properties.drop(0)
print(properties.head(30))
# Out:
# 0              ward_name    ward_id 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)
properties2 = pd.melt(properties, id_vars=["ward_name", "ward_id"], var_name="Year/Month", value_name="Avg price")
print(properties2)
# Out:
#                 ward_name    ward_id           Year/Month    Avg price
# 0          City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 1      Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 2                  Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 3                  Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 4                   Brent  E09000005  1995-01-01 00:00:00  71306.56698
# ...                   ...        ...                  ...          ...
# 16987              LONDON  E12000007  2024-06-01 00:00:00       523134
# 16988          SOUTH EAST  E12000008  2024-06-01 00:00:00       382522
# 16989          SOUTH WEST  E12000009  2024-06-01 00:00:00       317259
# 16990         Unnamed: 47        NaN  2024-06-01 00:00:00          NaN
# 16991             England  E92000001  2024-06-01 00:00:00       305370
#
# [16992 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties2.dtypes
properties2['Avg price'] = pd.to_numeric(properties2['Avg price'])
properties2.dtypes
# Out:
# ward_name      object
# ward_id        object
# Year/Month     object
# Avg price     float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
sample = {'name': ['John', 'Alice', 'Bob', 'Jane', 'Mike'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']}

df = pd.DataFrame(sample)
print(df)
print("---")
print(df.drop(df[df['name'] == 'Mike'].index))
# Out:
#     name  age         city
# 0   John   25     New York
# 1  Alice   30  Los Angeles
# 2    Bob   35      Chicago
# 3   Jane   40      Houston
# 4   Mike   45      Phoenix
# ---
#     name  age         city
# 0   John   25     New York
# 1  Alice   30  Los Angeles
# 2    Bob   35      Chicago
# 3   Jane   40      Houston

# %%
print(properties2.loc[:, 'ward_name'])


fugly = properties2[properties2['ward_id'].isna()]
print(fugly)
# Out:
# 0            City of London
# 1        Barking & Dagenham
# 2                    Barnet
# 3                    Bexley
# 4                     Brent
#                 ...
# 16987                LONDON
# 16988            SOUTH EAST
# 16989            SOUTH WEST
# 16990           Unnamed: 47
# 16991               England
# Name: ward_name, Length: 16992, dtype: object
#          ward_name ward_id           Year/Month  Avg price
# 33     Unnamed: 34     NaN  1995-01-01 00:00:00        NaN
# 36     Unnamed: 37     NaN  1995-01-01 00:00:00        NaN
# 46     Unnamed: 47     NaN  1995-01-01 00:00:00        NaN
# 81     Unnamed: 34     NaN  1995-02-01 00:00:00        NaN
# 84     Unnamed: 37     NaN  1995-02-01 00:00:00        NaN
# ...            ...     ...                  ...        ...
# 16932  Unnamed: 37     NaN  2024-05-01 00:00:00        NaN
# 16942  Unnamed: 47     NaN  2024-05-01 00:00:00        NaN
# 16977  Unnamed: 34     NaN  2024-06-01 00:00:00        NaN
# ...

# %%
properties3 = properties2.dropna()
print(properties3.head(50))
print(properties3.count())
# Out:
#                ward_name    ward_id           Year/Month     Avg price
# 0         City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.22660
# 2                 Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                 Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                  Brent  E09000005  1995-01-01 00:00:00   71306.56698
# 5                Bromley  E09000006  1995-01-01 00:00:00   81671.47692
# 6                 Camden  E09000007  1995-01-01 00:00:00  120932.88810
# 7                Croydon  E09000008  1995-01-01 00:00:00   69158.16225
# 8                 Ealing  E09000009  1995-01-01 00:00:00   79885.89069
# 9                Enfield  E09000010  1995-01-01 00:00:00   72514.69096
# 10             Greenwich  E09000011  1995-01-01 00:00:00   62300.10169
# 11               Hackney  E09000012  1995-01-01 00:00:00   61296.52637
# ...

# %%
sample = {'name': ['John', 'Alice', 'Bob', 'Jane', 'Mike'],
        'age': [25, 30, 35, 40, 45],
        'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']}

boys = ['John', 'Bob', 'Mike']

df = pd.DataFrame(sample)
print(df)
print("---")
print(df.drop(df[df['name'].isin(boys)].index))
# Out:
#     name  age         city
# 0   John   25     New York
# 1  Alice   30  Los Angeles
# 2    Bob   35      Chicago
# 3   Jane   40      Houston
# 4   Mike   45      Phoenix
# ---
#     name  age         city
# 1  Alice   30  Los Angeles
# 3   Jane   40      Houston

# %%
# Drop the other non-boroughs

print(properties3['ward_name'].unique())
non_boroughs = ['Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']

print("-----")

properties4 = properties3.drop(properties3[properties3['ward_name'].isin(non_boroughs)].index)
print(properties4['ward_name'].unique())

print("-----")



finalDF = properties4

print(finalDF.head(50))
# Out:
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster' 'Inner London' 'Outer London' 'NORTH EAST' 'NORTH WEST'
#  'YORKS & THE HUMBER' 'EAST MIDLANDS' 'WEST MIDLANDS' 'EAST OF ENGLAND'
#  'LONDON' 'SOUTH EAST' 'SOUTH WEST' 'England']
# -----
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
# ...

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
finalDF
# Out:
#                 ward_name    ward_id           Year/Month     Avg price
# 0          City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1      Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.22660
# 2                  Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                  Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                   Brent  E09000005  1995-01-01 00:00:00   71306.56698
# ...                   ...        ...                  ...           ...
# 16972              Sutton  E09000029  2024-06-01 00:00:00  426564.00000
# 16973       Tower Hamlets  E09000030  2024-06-01 00:00:00  456375.00000
# 16974      Waltham Forest  E09000031  2024-06-01 00:00:00  488279.00000
# 16975          Wandsworth  E09000032  2024-06-01 00:00:00  616803.00000
# 16976         Westminster  E09000033  2024-06-01 00:00:00  954279.00000
#
# [11682 rows x 4 columns]

# %%
# Barnet
barnet = finalDF[finalDF['ward_name']=='Barnet']
plt.plot(barnet['Year/Month'], barnet['Avg price'])
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# To find the greatest houes price increase, on average, over the past two decades, we actually just need the initial and final value.
# The last data point we have is 2024-06.
# So the first data point we need is 2004-06.
# Let's get rid of all the other months.

reducedTime = finalDF[(finalDF['Year/Month']=="2004-06") | (finalDF['Year/Month']=="2024-06")]

# desiredDates = ["2004-06", "2024-06"]
# reducedTime = finalDF.drop(finalDF[~finalDF['Year/Month'].isin(desiredDates)].index)
reducedTime
# Out:
#                 ward_name    ward_id Year/Month    Avg price
# 5424       City of London  E09000001 2004-06-01  297421.2464
# 5425   Barking & Dagenham  E09000002 2004-06-01  156950.5431
# 5426               Barnet  E09000003 2004-06-01  272859.2867
# 5427               Bexley  E09000004 2004-06-01  179977.0371
# 5428                Brent  E09000005 2004-06-01  239200.2710
# ...                   ...        ...        ...          ...
# 16972              Sutton  E09000029 2024-06-01  426564.0000
# 16973       Tower Hamlets  E09000030 2024-06-01  456375.0000
# 16974      Waltham Forest  E09000031 2024-06-01  488279.0000
# 16975          Wandsworth  E09000032 2024-06-01  616803.0000
# 16976         Westminster  E09000033 2024-06-01  954279.0000
#
# [66 rows x 4 columns]

# %%
# Split into separate dictionaries and use the merge methods
old = finalDF.copy()
old = old.drop(old[old['Year/Month'] != "2004-06"].index)
old.head(7)
# Out:
#                ward_name    ward_id Year/Month    Avg price
# 5424      City of London  E09000001 2004-06-01  297421.2464
# 5425  Barking & Dagenham  E09000002 2004-06-01  156950.5431
# 5426              Barnet  E09000003 2004-06-01  272859.2867
# 5427              Bexley  E09000004 2004-06-01  179977.0371
# 5428               Brent  E09000005 2004-06-01  239200.2710
# 5429             Bromley  E09000006 2004-06-01  232688.3160
# 5430              Camden  E09000007 2004-06-01  354540.4430

# %%
new = finalDF.copy()
new = new.drop(new[new['Year/Month'] != "2024-06"].index)
new.head(7)
# Out:
#                 ward_name    ward_id Year/Month  Avg price
# 16944      City of London  E09000001 2024-06-01   828527.0
# 16945  Barking & Dagenham  E09000002 2024-06-01   340403.0
# 16946              Barnet  E09000003 2024-06-01   585639.0
# 16947              Bexley  E09000004 2024-06-01   415496.0
# 16948               Brent  E09000005 2024-06-01   539180.0
# 16949             Bromley  E09000006 2024-06-01   497686.0
# 16950              Camden  E09000007 2024-06-01   809563.0

# %%
# Now merge them into one dataframe and add a new column for price difference
compare = old.merge(new, on=('ward_name', 'ward_id'), suffixes=['_old', '_new'])
compare['price difference'] = compare['Avg price_new'] - compare['Avg price_old']
compare
# Out:
#                ward_name    ward_id Year/Month_old  Avg price_old  \
# 0         City of London  E09000001     2004-06-01    297421.2464
# 1     Barking & Dagenham  E09000002     2004-06-01    156950.5431
# 2                 Barnet  E09000003     2004-06-01    272859.2867
# 3                 Bexley  E09000004     2004-06-01    179977.0371
# 4                  Brent  E09000005     2004-06-01    239200.2710
# 5                Bromley  E09000006     2004-06-01    232688.3160
# 6                 Camden  E09000007     2004-06-01    354540.4430
# 7                Croydon  E09000008     2004-06-01    199032.9433
# 8                 Ealing  E09000009     2004-06-01    243308.0087
# 9                Enfield  E09000010     2004-06-01    208076.2318
# 10             Greenwich  E09000011     2004-06-01    187008.9178
# 11               Hackney  E09000012     2004-06-01    210881.9122
# 12  Hammersmith & Fulham  E09000013     2004-06-01    349699.9703
# ...

# %%
# Sort from biggest to smallest difference
compare = compare.sort_values(by='price difference', ascending=False)
compare
# Out:
#                ward_name    ward_id Year/Month_old  Avg price_old  \
# 19  Kensington & Chelsea  E09000020     2004-06-01    492777.5322
# 32           Westminster  E09000033     2004-06-01    394039.3101
# 0         City of London  E09000001     2004-06-01    297421.2464
# 6                 Camden  E09000007     2004-06-01    354540.4430
# 12  Hammersmith & Fulham  E09000013     2004-06-01    349699.9703
# 26  Richmond upon Thames  E09000027     2004-06-01    320264.4917
# 18             Islington  E09000019     2004-06-01    282674.3727
# 11               Hackney  E09000012     2004-06-01    210881.9122
# 31            Wandsworth  E09000032     2004-06-01    273488.5633
# 23                Merton  E09000024     2004-06-01    238638.7310
# 2                 Barnet  E09000003     2004-06-01    272859.2867
# 21               Lambeth  E09000022     2004-06-01    220816.9370
# 13              Haringey  E09000014     2004-06-01    233500.1154
# ...

# %%
# Now plot a bar graph
compare.plot.bar(x='ward_name', y='price difference')
plt.show()

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
#
# - Python Data Science Toolbox - Part One, all modules

# %%
# Define a function to provide the ratio of Avg_price_1998/Avg_price_2018

def AvgPriceOfBorough_1998_2018(borough):
    # First convert TimeStamp to TimeStamp objects
    finalDF['Year/Month'] = pd.to_datetime(finalDF['Year/Month'])

    # Subset for a specific borough
    data_on_borough = finalDF[finalDF['ward_name'] == borough]

    # Two subset dataframes, for 1998 and 2018
    data_1998 = data_on_borough[(data_on_borough['Year/Month'] >= "1998") & (data_on_borough['Year/Month'] < "1999")]
    data_2018 = data_on_borough[(data_on_borough['Year/Month'] >= "2018") & (data_on_borough['Year/Month'] < "2019")]

    # Calculate the average price for each year
    avg_price_1998 = data_1998['Avg price'].mean()
    avg_price_2018 = data_2018['Avg price'].mean()

    # Ratio of 1998/2018 prices
    ratio = avg_price_1998/avg_price_2018
    print("The ratio is", ratio)

    return ratio

AvgPriceOfBorough_1998_2018("Croydon")
# Out:
# The ratio is 0.23803288028014052
# 0.23803288028014052

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# This was a very fun project! I liked getting to use a project to help solidify and summarize my own understanding, while also giving me autonomy to make my own decisions on what to do next.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# My steps:
# 1.) Present the data in readable format. This entails melting the dataframe, removing rows with irrelevant data, properly labeling the columns and indexing, transposing the axes, etc.
# 2.) After the data was cleaned and ready for manipulation, I began to address the actual question. Which borough has had the greatest increase in average housing prices over 2 decades? The most recent data point we had was June 2024, so I wanted to compare it with June 2004. We then found the difference in price for each borough between those 2 specific months. From there, we sorted the data and graphed it so it was easy to identify the answer: Kensington & Chelsea.
# 3.) We also created a function to quickly identify the ratio of average housing prices from 1998 to 2018, given a specific borough. We used the borough as the parameter for the function, and subset the data into 2 dataframes: one with data from 1998 and another from 2018. We found the mean from each year and divided the two results.
#
# My favorite part was working with the clean data to create visuals, make new insights, and subset relevant data to our question. It was the part of the project in which I was finally allowed to actually start thinking about the original question. I also really enjoyed defining the function for the modeling part. I think creating functions is really fun and gave me another fun problem to work through.
#
#
# The part I struggled the most with was cleaning up the data. Since this was my first time, I wasn't really sure what I was looking at. I didn't understand what "Unnamed city: 34" referred to. I also didn't realize that "Inner London" doesn't count as a borough. I needed some direction from the Tier 2 assignment to help me figure out what to do during this stage.
#
# A specific problem I ran into was the DateTime object. Originally, I disliked the format presented, so I created a loop to rename all the columns into a string with the format "YYYY-MM", so that I didn't have to look at the day or time. This created a string, which later became a problem when I wanted to subset a specific dataframe based on year (or range of years). It became harder to use conditional statements with strins intead of DateTime. I tried converting it from string to datetime (which I struggled with), or combine .isin and .contains() (which won't work on Dataframes). Eventually, I dropped my initial column renaming and allowed it to stay in DateTime format. However, I still needed to convert it into a DateTime Object, so I could manipulate it. That code was a lot easier than my previous methods.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
